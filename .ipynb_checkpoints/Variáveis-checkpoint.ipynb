% %% [raw]
% TIPOS DE VARIÁVEIS
% Existe basicamente 5 divisóes principais de variáveis:
%
%
% 1) As reais e inteiras (double array-variáveis númericas)
%
%
% 2) As complexas (double array complex-variáveis númericas)
%
%
% 3) As caracther (char array -varáveis de texto)
%
%
% 4) As células (cell array -permite armazenamento de variáveis de tipos diferentes no formato celular do Matlab)
%
%
% 5) As estruturas (struct array -permite armazenamento de variáveis de tipos (potencialmente) diferentes no formato celular do Matlab).

% %% [raw]
% Reais inteiros ou complexos em diferentes formatos.

% %%
clear;
clc;
%%Reais inteiros ou complexos em diferentes formatos %%
format long e
a = 1.3
format rat
b = 3.14
format long 
c = pi
format short e
d = 1e-2
format +
e = 1
format +
f = -1
format +
g = 0
format short
z = a + c*i


whos;
% Out:
% a =
%
%      1.300000000000000e+00
%
%
% b =
%
%      157/50
%
%
% c =
%
%    3.141592653589793
%
%
% d =
%
%    1.0000e-02
%
%
% e =
%
% +
%
%
% f =
%
% -
%
%
% g =
%
%
%
%
% z =
%
%    1.3000 + 3.1416i
%
%   Name      Size            Bytes  Class     Attributes
%
%   a         1x1                 8  double
%   b         1x1                 8  double
%   c         1x1                 8  double
%   d         1x1                 8  double
%   e         1x1                 8  double
%   f         1x1                 8  double
%   g         1x1                 8  double
%   z         1x1                16  double    complex

% %% [raw]
% Vetores, Matrizes e Textos

% %%
clear;
clc;

%%Vetores%%
v = [1,2,3]
w = [1 2 3]
u = [1;2;3]

%%Matrizes%%
A = [1 2 3;4 5 6]

%%Texto%%
z_1 = 'Hello word. Quando o relógio bate às onze,todas as caveiras saem da tumba. tumbalacatumbatumbata';
disp(z_1);
whos;
% Out:
% v =
%
%      1     2     3
%
%
% w =
%
%      1     2     3
%
%
% u =
%
%      1
%      2
%      3
%
%
% A =
%
%      1     2     3
%      4     5     6
%
% Hello word. Quando o relógio bate às onze,todas as caveiras saem da tumba. tumbalacatumbatumbata
%   Name      Size            Bytes  Class     Attributes
%
%   A         2x3                48  double
%   u         3x1                24  double
%   v         1x3                24  double
%   w         1x3                24  double
%   z_1       1x96              192  char

% %% [raw]
% Células e Estruturas.

% %%
clear;
clc;

%%Célula%%
B=cell(2,3)  %Construíndo uma célula vazia

             %Construíndo uma célula com conteúdo diverso célula-à-célula
Z(1,1) = {reshape(1:9,3,3)};
Z(1,2) = {2+3i};
Z(2,1) = {'Uma string'};
Z(2,2) = {12:-2:0}

             %Construíndo uma célula com conteúdo diverso célula-à-célula
z_2 = {'Algebra Linear', 205, [1208, 1508];
            'Calculo',        346, [1009, 1209];    
            'Geometria',      123, [0408, 0509];  
            'Topologia',      253, [0108, 0409] };
%vendo cada componente (uma matriz, um vetor, um número complexo,ou uma string) da Célula Z.           
celldisp(Z)

%%Estruturas%
format long g
z_3= struct('Nome',{'Francisco Mateus Andrade Castelo branco'},'Vocativo',{'Castelo'},'Idade',{23},'Nacionalidade',{'Brasileiro'},'Curso',{'Eng. Elétrica'},'CPF',{'XXX.XXX.XXX-50'},'Matricula',{2015084566})

whos;
% Out:
% B =
%
%     []    []    []
%     []    []    []
%
%
% Z =
%
%     [3x3 double]    [2 +                     3i]
%     'Uma string'                    [1x7 double]
%
%
% Z{1,1} =
%
%      1     4     7
%      2     5     8
%      3     6     9
%
%
%
% Z{2,1} =
%
% Uma string
%
%
% Z{1,2} =
%
%                           2 +                     3i
%
%
%
% Z{2,2} =
%
%     12    10     8     6     4     2     0
%
%
%
% z_3 =
%
%              Nome: 'Francisco Mateus Andrade Castelo branco'
%          Vocativo: 'Castelo'
%             Idade: 23
%     Nacionalidade: 'Brasileiro'
%             Curso: 'Eng. Elétrica'
%               CPF: 'XXX.XXX.XXX-50'
%         Matricula: 2015084566
%
%   Name      Size            Bytes  Class     Attributes
%
%   B         2x3                48  cell
%   Z         2x2               612  cell
%   z_2       4x3              1518  cell
%   z_3       1x1              1414  struct

% %% [raw]
% A maior parte da documentção das variáveis e os seus tipos se encontra nos própios comentários do código Matlab.
% Segue abaixo o código na integra:
%
%
% %%%TIPOS DE VARIÁVEIS%%%%
% %
% %Existe basicamente 5 divisóes principais de variáveis:
%
% % 1) As reais e inteiras (double array-variáveis númericas)
%
% % 2) As complexas (double array complex-variáveis númericas)
%
% % 3) As caracther (char array -varáveis de texto)
%
% % 4) As células (cell array -permite armazenamento de variáveis de tipos
% % diferentes no formato celular do Matlab)
%
% % 5) As estruturas (struct array -permite armazenamento de variáveis de tipos
% % (potencialmente)diferentes no formato celular do Matlab)
%
% clear;
% clc;
% %%Reais inteiros ou complexos em diferentes formatos %%
% format long e
% a = 1.3
% format rat
% b = 3.14
% format long
% c = pi
% format short e
% d = 1e-2
% format +
% e = 1
% format +
% f = -1
% format +
% g = 0
% format short
% z = a + c*i
%
% %%Vetores%%
% v = [1,2,3]
% w = [1 2 3]
% u = [1;2;3]
%
% %%Matrizes%%
% A = [1 2 3;4 5 6]
%
% %%Texto%%
% z_1 = 'Hello word. Quando o relógio bate às onze,todas as caveiras saem da tumba. tumbalacatumbatumbata';
% disp(z_1);
%
% %%Célula%%
% B=cell(2,3)  %Construíndo uma célula vazia
%
%              %Construíndo uma célula com conteúdo diverso célula-à-célula
% Z(1,1) = {reshape(1:9,3,3)}
% Z(1,2) = {2+3i}
% Z(2,1) = {'Uma string'}
% Z(2,2) = {12:-2:0}
%
%              %Construíndo uma célula com conteúdo diverso célula-à-célula
% z_2 = {'Algebra Linear', 205, [1208, 1508];
%             'Calculo',        346, [1009, 1209];
%             'Geometria',      123, [0408, 0509];
%             'Topologia',      253, [0108, 0409] }
%
% celldisp(Z)
%
% %%Estruturas%
% format long g
% z_3= struct('Nome',{'Castelo'},'Idade',{23},'Nacionalidade',{'Brasileiro'},'Curso',{'Eng. Elétrica'},'CPF',{'XXX.XXX.XXX-50'},'Matricula',{2015084566})
%
% whos;
